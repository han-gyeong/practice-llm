# %%
# %pip install -q langchain-openai python-dotenv
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
ai_message = llm.invoke("삼겹살을 숯불에 맛있게 굽는 방법이 무엇인가요?")
ai_message.content
# Out:
# '1. 냉장고에서 미리 꺼내 둔 삼겹살을 씻어 깨끗하게 만든다.\n2. 삼겹살의 물기를 키친타올로 닦아 낸다.\n3. 삼겹살의 두툼한 부분은 칼로 살짝 가르거나 가늘게 썰어준다.\n4. 숯불을 피우고 꽉 채울 때까지 기다린다.\n5. 삼겹살을 숯불에 올려주고 뒤집는다.\n6. 삼겹살의 양쪽 면이 골고루 익도록 주의한다.\n7. 적당한 섭지끗을 먹을만큼 익으면 그릇에 담아 가져온 소금에 찍어먹는다.\n\n추가로, 삼겹살 맛있게 굽는 팁은 삼겹살을 잠시 냉동실에 넣고 얼려 꽉 깍두기한 후 더 바삭한 맛을 냄으로서 최종적으로 더 맛있게 즐길 수 있습니다.'
